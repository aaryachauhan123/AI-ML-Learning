# %% [markdown]
# <a href="https://colab.research.google.com/github/aaryachauhan123/AI-ML-Learning/blob/main/Object_detection.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip -q install ultralytics
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 59.4 MB/s eta 0:00:00

# %%
from ultralytics import YOLO
model = YOLO('yolov8n.pt') #small + fast pre trained model

# %%
import matplotlib.pyplot as plt

result = model('/content/people.jpg')


im=result[0].plot()
display(im)
# Out:
# image 1/1 /content/people.jpg: 448x640 10 persons, 487.0ms
# Speed: 20.1ms preprocess, 487.0ms inference, 1.7ms postprocess per image at shape (1, 3, 448, 640)
# array([[[216, 223, 220],
#         [211, 218, 215],
#         [211, 218, 215],
#         ...,
#         [ 43,  68,  58],
#         [ 27,  54,  50],
#         [ 20,  51,  50]],
#
#        [[211, 218, 215],
#         [206, 213, 210],
#         [206, 213, 210],
#         ...,
#         [ 37,  61,  51],
#         [ 32,  57,  53],
#         [ 33,  62,  59]],
#
#        [[207, 214, 211],
#         [201, 208, 205],
#         [200, 207, 204],
#         ...,
#         [ 40,  60,  48],
#         [ 40,  62,  57],
#         [ 45,  68,  64]],
#
#        ...,
#
#        [[193, 170, 222],
#         [191, 168, 220],
#         [188, 164, 218],
#         ...,
#         [255,  42,   4],
#         [255,  42,   4],
#         [255,  42,   4]],
#
#        [[203, 180, 232],
#         [201, 178, 230],
#         [198, 174, 228],
#         ...,
# ...

# %%
result = model('/content/fruit.jpg')
result[0].show()
# Out:
# image 1/1 /content/fruit.jpg: 384x640 3 apples, 2 oranges, 147.3ms
# Speed: 4.7ms preprocess, 147.3ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# <PIL.Image.Image image mode=RGB size=321x180>

# %%
result = model('/content/vegis.jpg')
result[0].show()
# Out:
# image 1/1 /content/vegis.jpg: 288x640 3 oranges, 2 broccolis, 1 dining table, 171.2ms
# Speed: 3.7ms preprocess, 171.2ms inference, 1.4ms postprocess per image at shape (1, 3, 288, 640)
# <PIL.Image.Image image mode=RGB size=420x180>

# %%
result = model('/content/animal.jpg')
result[0].show()
# Out:
# image 1/1 /content/animal.jpg: 448x640 1 bird, 1 dog, 1 sheep, 1 cow, 2 giraffes, 254.8ms
# Speed: 4.4ms preprocess, 254.8ms inference, 1.7ms postprocess per image at shape (1, 3, 448, 640)
# <PIL.Image.Image image mode=RGB size=270x180>

# %%
result = model('/content/electronics.jpg')
result[0].show()
# Out:
# image 1/1 /content/electronics.jpg: 384x640 1 laptop, 2 keyboards, 2 cell phones, 130.9ms
# Speed: 3.3ms preprocess, 130.9ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# <PIL.Image.Image image mode=RGB size=321x180>

# %%
result = model('/content/vehicals2.jpg')
result[0].show()
# Out:
# image 1/1 /content/vehicals2.jpg: 352x640 1 bicycle, 4 cars, 2 motorcycles, 1 bus, 1 truck, 131.1ms
# Speed: 3.4ms preprocess, 131.1ms inference, 1.1ms postprocess per image at shape (1, 3, 352, 640)
# <PIL.Image.Image image mode=RGB size=342x180>
